# %% [markdown]
# # Q.1- Given the following Series1
#
#             A 100
#             B 200
#             C 300
#             D 400
#             E 500
# Write the command to create above Series and then double the value in series and store in another series named Series2

# %%
import pandas as pd
Series1 = pd.Series([100,200,300,400,500],
                    index=['A','B','C','D','E'])
Series2 = Series1 * 2

print("Series1:")
print(Series1)
print("\nSeries2:")
print(Series2)
# Out:
# Series1:
# A    100
# B    200
# C    300
# D    400
# E    500
# dtype: int64
#
# Series2:
# A     200
# B     400
# C     600
# D     800
# E    1000
# dtype: int64

# %% [markdown]
# # Q.2-
#
# a. Series object is size mutable = `False`
#
#
#
#
# b. DataFrame object is value mutable =`True`

# %% [markdown]
# # Q.3- Consider a given Series , Series1:
#
#                                   200 700
#                                   201 700
#                                   202 700
#                                   203 700
#                                   204 700
# Write a program in Python Pandas to create theseries and display it.

# %%
import pandas as pd
Series1 = pd.Series([700,700,700,700,700],
                    index=[200,201,202,203,204])
print(Series1)
# Out:
# 200    700
# 201    700
# 202    700
# 203    700
# 204    700
# dtype: int64

# %% [markdown]
# # Q.4- Consider the following Series object,
#
#                             sIP 95
#                             Physics 89
#                             Chemistry 92
#                             Math 95
# i. Write the Python syntax which will displayonly IP.
#
# ii. Write the Python syntax to increase marks of all subjects by 10.

# %%
sIP = pd.Series([95,89,92,95],
                index=['IP','Physics','Chemistry','Math'])

print("Only IP:", sIP['IP'])
print("\nMarks increased by 10:")
print(sIP + 10)

# %% [markdown]
# # Q.5- Consider a given series : SQTR
#
#                       QTR1 50000
#                       QTR2 65890
#                       QTR3 56780
#                       QTR4 89000
#                       QTR5 77900
# Write a program in Python Pandas to create and display the series.

# %%
import pandas as pd
SQTR = pd.Series([50000,65890,56780,89000,77900],
                 index=['QTR1','QTR2','QTR3','QTR4','QTR5'])
print(SQTR)

# %% [markdown]
# # Q.6- What will be the output produced by the following programming statements 1 & 2?
#
# import pandas as pd
#
# S1=pd.Series(data=[31,41,51])
#
# print(S1>40) -->Statement1
#
# print(S1[S1>40]) -->Statement2

# %%
import pandas as pd
S1 = pd.Series([31,41,51])

print(S1 > 40)
print(S1[S1 > 40])
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool
# 1    41
# 2    51
# dtype: int64

# %% [markdown]
# # Q.7- Given two series S1 and S2
# S1 S2 A 39 A 10 B 41 B 10 C 42 D 10 D 44 F 10 Find the output for following python pandas statements?
#
# a. S1[ : 2]*100
#
# b. S1 * S2
#
# c. S2[ : : -1]*10

# %%
S1 = pd.Series([39,41,42,44], index=['A','B','C','D'])
S2 = pd.Series([10,10,10,10], index=['A','B','D','F'])

print(S1[:2] * 100)
print(S1 * S2)
print(S2[::-1] * 10)
# Out:
# A    3900
# B    4100
# dtype: int64
# A    390.0
# B    410.0
# C      NaN
# D    440.0
# F      NaN
# dtype: float64
# F    100
# D    100
# B    100
# A    100
# dtype: int64

# %% [markdown]
# # Q.8- Given the following Series S1 and S2:
#
#                    S1   S2
#                    A 10 A 5
#                    B 20 B 4
#                    C 30 C 6
#                    D 40 D 8
# Write the command to find the multiplication of series S1 and S2

# %%
S1 = pd.Series([10,20,30,40], index=['A','B','C','D'])
S2 = pd.Series([5,4,6,8], index=['A','B','C','D'])

print(S1 * S2)

# %% [markdown]
# # Q.9- Consider a given Series , Subject:
#
# ENGLISH 75
#
# HINDI 78
#
# MATHS 82
#
# SCIENCE 86
#
# Write a program in Python Pandas to create this series

# %%
Subject = pd.Series([75,78,82,86],
                     index=['ENGLISH','HINDI','MATHS','SCIENCE'])
print(Subject)
# Out:
# ENGLISH    75
# HINDI      78
# MATHS      82
# SCIENCE    86
# dtype: int64

# %% [markdown]
# # Q.10- Consider the following Series object, “company” and its profit in Crores
#
# TCS 350
#
# Reliance 200
#
# L&T 800
#
# Wipro 150
#
# i. Write the command which will display the name of the company having profit>250.
#
#  ii. Write the command to name the series as Profit.

# %%
company = pd.Series([350,200,800,150],
                     index=['TCS','Reliance','L&T','Wipro'])

print(company[company > 250].index)

company.name = "Profit"
print(company)

# %% [markdown]
# # Q.11- Consider two objects a and b.
# a is a list whereas b is a Series. Both have values 10,20,25,50.
# What will be the output of the following two statements considering that the above objects have been created already
#
# a. print(a*2)
#
# b. print(b*2)
#
# Justify your answer.

# %%
a = [10,20,25,50]
b = pd.Series([10,20,25,50])

print(a * 2)
print(b * 2)
# Out:
# [10, 20, 25, 50, 10, 20, 25, 50]
# 0     20
# 1     40
# 2     50
# 3    100
# dtype: int64

# %% [markdown]
# # Q.12- Given a Pandas series called Sample, the command which will display the last 3 rows is .
#
# a. print(Sample.tail(3))
#
# b. print(Sample.Tail(3))
#
# c. print(Sample.tails(3)
#
# d. print(Sample.Tails(3))

# %% [markdown]
# **`Ans :- c`**

# %% [markdown]
# # Q.13- What will be the output of the following code?
#
# import pandas as pd
#
# s = pd.Series(6,index=ran(0ge,5))
#
# print(s)

# %% [markdown]
# ```
# Output:-
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# ```

# %% [markdown]
# # Q.14- If series s1 is having following data,
#
# ```
# 1   6
# 3   1
# 5   3
# 7   5
# 9   4
# 11  8
# 13  7
# 15  4
# 17  6
# 19  7
# dtype:int64
# ```
# What would be the result of the command print(s1[3:6])?

# %% [markdown]
# ```
# Ans :- result of print(s1[3:6])
#
# 7     5
# 9     4
# 11    8
# dtype: int64
# ```

# %% [markdown]
# # Q.15- What will be the output of the following code?
# ```
# import pandas as pd
#
# import numpy as np
#
# s = pd.Series(np.arange(10,50,10)) print(s)
#
# print (s.ndim)
#
# print(s.shape)
#
# print(len(s))
# ```

# %% [markdown]
# ```
# # Output:-
# ```
# ```
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 1
# (4,)
# 4
# ```

# %% [markdown]
# # Q.16- Write a program to create a Series having 10 random numbers in the range of 10 and 20

# %%
s = pd.Series(np.random.randint(10,20,10))
print(s)
# Out:
# 0    19
# 1    14
# 2    13
# 3    13
# 4    19
# 5    12
# 6    17
# 7    14
# 8    11
# 9    16
# dtype: int64

# %% [markdown]
# # Q.17- Consider the following Series ‘s’-
# ```
# 0 4.0
# 1 5.0
# 2 7.0
# 3 NaN
# 4 1.0
# 5 10.0
# dtype: float64
# (i) Write a Python code to add 1 to all the elements.
# (ii) Write a code to replace all NaN with 0.
# ```

# %%
s = pd.Series([4.0,5.0,7.0,np.nan,1.0,10.0])

print(s + 1)
print(s.fillna(0))
# Out:
# 0     5.0
# 1     6.0
# 2     8.0
# 3     NaN
# 4     2.0
# 5    11.0
# dtype: float64
# 0     4.0
# 1     5.0
# 2     7.0
# 3     0.0
# 4     1.0
# 5    10.0
# dtype: float64

# %% [markdown]
# # Q.18- Predict the output of the following code.
#
# import pandas as pd
#
# import numpy as np
#
# data = {'one':'a','two':'b','three':'c'}
#
# s=pd.Series(data)
#
# print(s)
#
# print(s.size)

# %% [markdown]
# # Output:-
# ```
# one      a
# two      b
# three    c
# dtype: object
# 3
# ```

# %% [markdown]
# # Q.19- Create a Series object S1 using a python sequence [2,4,6,8] and default indices.

# %%
S1 = pd.Series([2,4,6,8])
print(S1)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %% [markdown]
# # Q.20-Write the output of the following code fragment.
#
# import pandas as pd
#
# s2=pd.Series(["i","am", "a","student"])
#
# print(s2)

# %% [markdown]
# # Output:-
# ```
# 0          i
# 1         am
# 2          a
# 3    student
# dtype: object
# ```
